# %% [markdown]
# # Performantly Quantize LLMs to 4-bits with Marlin and nm-vllm
#
# This notebook walks through how to compress a pretrained LLM and deploy it with `nm-vllm`. To create a new 4-bit quantized model, we can leverage AutoGPTQ. Quantizing reduces the model's precision from FP16 to INT4 which effectively reduces the file size by ~70%. The main benefits are lower latency and memory usage.
#
# Developed in collaboration with IST-Austria, [GPTQ](https://arxiv.org/abs/2210.17323) is the leading quantization algorithm for LLMs, which enables compressing the model weights from 16 bits to 4 bits with limited impact on accuracy. [nm-vllm](https://github.com/neuralmagic/nm-vllm) includes support for the recently-developed Marlin kernels for accelerating GPTQ models. Prior to Marlin, the existing kernels for INT4 inference failed to scale in scenarios with multiple concurrent users.
#
# This notebook requires an NVIDIA GPU with compute capability >= 8.0 (>=Ampere) because of Marlin kernel restrictions. This will not run on T4 or V100 currently. This was tested on an A100 on Colab.

# %%
# !nvidia-smi
# Out:
# Tue Mar  5 20:22:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              49W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install AutoGPTQ
#
# AutoGPTQ is an easy-to-use LLM quantization package with user-friendly APIs, based on the GPTQ algorithm (weight-only quantization).

# %%
# !pip install auto-gptq==0.7.1 torch==2.2.1

# %% [markdown]
# ## Quantizing an LLM
#
# After installing AutoGPTQ, you are ready to quantize a model.
#
# Below is an example of how to quantize [TinyLlama 1B Chat v1.0](https://huggingface.co/TinyLlama/TinyLlama-1.1B-Chat-v1.0) using GPTQ.
#
# We will be using 512 samples from the [ultrachat_200k](https://huggingface.co/datasets/HuggingFaceH4/ultrachat_200k) dataset so we load and tokenize those samples first.

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

MAX_SEQ_LEN = 512
NUM_EXAMPLES = 512

MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
DATASET = "HuggingFaceH4/ultrachat_200k"

def preprocess(example):
    return {"text": tokenizer.apply_chat_template(example["messages"], tokenize=False)}

dataset = load_dataset(DATASET, split="train_sft")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
ds = dataset.shuffle().select(range(NUM_EXAMPLES))
ds = ds.map(preprocess)

examples = [
    tokenizer(
        example["text"], padding=False, max_length=MAX_SEQ_LEN, truncation=True,
    ) for example in ds
]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/243M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/243M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Map:   0%|          | 0/512 [00:00<?, ? examples/s]

# %% [markdown]
# ## Apply GPTQ
#
# Next we will actually apply GPTQ with the samples we've process from the dataset.

# %%
from auto_gptq import AutoGPTQForCausalLM, BaseQuantizeConfig

quantize_config = BaseQuantizeConfig(
    bits=4,                         # Only support 4 bit
    group_size=128,                 # Set to g=128 or -1 (for channelwise)
    desc_act=False,                 # Marlin does not support act_order=True
    model_file_base_name="model",   # Name of the model.safetensors when we call save_pretrained
)

model = AutoGPTQForCausalLM.from_pretrained(
    MODEL_ID,
    quantize_config,
    device_map="auto")
model.quantize(examples)

gptq_save_dir = f"{MODEL_ID.split('/')[-1]}-gptq"
print(f"Saving gptq model to {gptq_save_dir}")
model.save_pretrained(gptq_save_dir)
tokenizer.save_pretrained(gptq_save_dir)

import gc
del model
gc.collect()
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# INFO - Start quantizing layer 1/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 1/22
# INFO - Quantizing self_attn.k_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 1/22...
# INFO - Quantizing self_attn.v_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 1/22...
# INFO - Quantizing self_attn.q_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 1/22...
# INFO - Quantizing self_attn.o_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 1/22...
# INFO - Quantizing mlp.up_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 1/22...
# INFO - Quantizing mlp.gate_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 1/22...
# INFO - Quantizing mlp.down_proj in layer 1/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 1/22...
# INFO - Start quantizing layer 2/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 2/22
# INFO - Quantizing self_attn.k_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 2/22...
# INFO - Quantizing self_attn.v_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 2/22...
# INFO - Quantizing self_attn.q_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 2/22...
# INFO - Quantizing self_attn.o_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 2/22...
# INFO - Quantizing mlp.up_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 2/22...
# INFO - Quantizing mlp.gate_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 2/22...
# INFO - Quantizing mlp.down_proj in layer 2/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 2/22...
# INFO - Start quantizing layer 3/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 3/22
# INFO - Quantizing self_attn.k_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 3/22...
# INFO - Quantizing self_attn.v_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 3/22...
# INFO - Quantizing self_attn.q_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 3/22...
# INFO - Quantizing self_attn.o_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 3/22...
# INFO - Quantizing mlp.up_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 3/22...
# INFO - Quantizing mlp.gate_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 3/22...
# INFO - Quantizing mlp.down_proj in layer 3/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 3/22...
# INFO - Start quantizing layer 4/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 4/22
# INFO - Quantizing self_attn.k_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 4/22...
# INFO - Quantizing self_attn.v_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 4/22...
# INFO - Quantizing self_attn.q_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 4/22...
# INFO - Quantizing self_attn.o_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 4/22...
# INFO - Quantizing mlp.up_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 4/22...
# INFO - Quantizing mlp.gate_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 4/22...
# INFO - Quantizing mlp.down_proj in layer 4/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 4/22...
# INFO - Start quantizing layer 5/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 5/22
# INFO - Quantizing self_attn.k_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 5/22...
# INFO - Quantizing self_attn.v_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 5/22...
# INFO - Quantizing self_attn.q_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 5/22...
# INFO - Quantizing self_attn.o_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 5/22...
# INFO - Quantizing mlp.up_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 5/22...
# INFO - Quantizing mlp.gate_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 5/22...
# INFO - Quantizing mlp.down_proj in layer 5/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 5/22...
# INFO - Start quantizing layer 6/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 6/22
# INFO - Quantizing self_attn.k_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 6/22...
# INFO - Quantizing self_attn.v_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 6/22...
# INFO - Quantizing self_attn.q_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 6/22...
# INFO - Quantizing self_attn.o_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 6/22...
# INFO - Quantizing mlp.up_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 6/22...
# INFO - Quantizing mlp.gate_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 6/22...
# INFO - Quantizing mlp.down_proj in layer 6/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 6/22...
# INFO - Start quantizing layer 7/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 7/22
# INFO - Quantizing self_attn.k_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 7/22...
# INFO - Quantizing self_attn.v_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 7/22...
# INFO - Quantizing self_attn.q_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 7/22...
# INFO - Quantizing self_attn.o_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 7/22...
# INFO - Quantizing mlp.up_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 7/22...
# INFO - Quantizing mlp.gate_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 7/22...
# INFO - Quantizing mlp.down_proj in layer 7/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 7/22...
# INFO - Start quantizing layer 8/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 8/22
# INFO - Quantizing self_attn.k_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 8/22...
# INFO - Quantizing self_attn.v_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 8/22...
# INFO - Quantizing self_attn.q_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 8/22...
# INFO - Quantizing self_attn.o_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 8/22...
# INFO - Quantizing mlp.up_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 8/22...
# INFO - Quantizing mlp.gate_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 8/22...
# INFO - Quantizing mlp.down_proj in layer 8/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 8/22...
# INFO - Start quantizing layer 9/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 9/22
# INFO - Quantizing self_attn.k_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 9/22...
# INFO - Quantizing self_attn.v_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 9/22...
# INFO - Quantizing self_attn.q_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 9/22...
# INFO - Quantizing self_attn.o_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 9/22...
# INFO - Quantizing mlp.up_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 9/22...
# INFO - Quantizing mlp.gate_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 9/22...
# INFO - Quantizing mlp.down_proj in layer 9/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 9/22...
# INFO - Start quantizing layer 10/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 10/22
# INFO - Quantizing self_attn.k_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 10/22...
# INFO - Quantizing self_attn.v_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 10/22...
# INFO - Quantizing self_attn.q_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 10/22...
# INFO - Quantizing self_attn.o_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 10/22...
# INFO - Quantizing mlp.up_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 10/22...
# INFO - Quantizing mlp.gate_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 10/22...
# INFO - Quantizing mlp.down_proj in layer 10/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 10/22...
# INFO - Start quantizing layer 11/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 11/22
# INFO - Quantizing self_attn.k_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 11/22...
# INFO - Quantizing self_attn.v_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 11/22...
# INFO - Quantizing self_attn.q_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 11/22...
# INFO - Quantizing self_attn.o_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 11/22...
# INFO - Quantizing mlp.up_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 11/22...
# INFO - Quantizing mlp.gate_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 11/22...
# INFO - Quantizing mlp.down_proj in layer 11/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 11/22...
# INFO - Start quantizing layer 12/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 12/22
# INFO - Quantizing self_attn.k_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 12/22...
# INFO - Quantizing self_attn.v_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 12/22...
# INFO - Quantizing self_attn.q_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 12/22...
# INFO - Quantizing self_attn.o_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 12/22...
# INFO - Quantizing mlp.up_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 12/22...
# INFO - Quantizing mlp.gate_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 12/22...
# INFO - Quantizing mlp.down_proj in layer 12/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 12/22...
# INFO - Start quantizing layer 13/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 13/22
# INFO - Quantizing self_attn.k_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 13/22...
# INFO - Quantizing self_attn.v_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 13/22...
# INFO - Quantizing self_attn.q_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 13/22...
# INFO - Quantizing self_attn.o_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 13/22...
# INFO - Quantizing mlp.up_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 13/22...
# INFO - Quantizing mlp.gate_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 13/22...
# INFO - Quantizing mlp.down_proj in layer 13/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 13/22...
# INFO - Start quantizing layer 14/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 14/22
# INFO - Quantizing self_attn.k_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 14/22...
# INFO - Quantizing self_attn.v_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 14/22...
# INFO - Quantizing self_attn.q_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 14/22...
# INFO - Quantizing self_attn.o_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 14/22...
# INFO - Quantizing mlp.up_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 14/22...
# INFO - Quantizing mlp.gate_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 14/22...
# INFO - Quantizing mlp.down_proj in layer 14/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 14/22...
# INFO - Start quantizing layer 15/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 15/22
# INFO - Quantizing self_attn.k_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 15/22...
# INFO - Quantizing self_attn.v_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 15/22...
# INFO - Quantizing self_attn.q_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 15/22...
# INFO - Quantizing self_attn.o_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 15/22...
# INFO - Quantizing mlp.up_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 15/22...
# INFO - Quantizing mlp.gate_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 15/22...
# INFO - Quantizing mlp.down_proj in layer 15/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 15/22...
# INFO - Start quantizing layer 16/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 16/22
# INFO - Quantizing self_attn.k_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 16/22...
# INFO - Quantizing self_attn.v_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 16/22...
# INFO - Quantizing self_attn.q_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 16/22...
# INFO - Quantizing self_attn.o_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 16/22...
# INFO - Quantizing mlp.up_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 16/22...
# INFO - Quantizing mlp.gate_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 16/22...
# INFO - Quantizing mlp.down_proj in layer 16/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 16/22...
# INFO - Start quantizing layer 17/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 17/22
# INFO - Quantizing self_attn.k_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 17/22...
# INFO - Quantizing self_attn.v_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 17/22...
# INFO - Quantizing self_attn.q_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 17/22...
# INFO - Quantizing self_attn.o_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 17/22...
# INFO - Quantizing mlp.up_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 17/22...
# INFO - Quantizing mlp.gate_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 17/22...
# INFO - Quantizing mlp.down_proj in layer 17/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 17/22...
# INFO - Start quantizing layer 18/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 18/22
# INFO - Quantizing self_attn.k_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 18/22...
# INFO - Quantizing self_attn.v_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 18/22...
# INFO - Quantizing self_attn.q_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 18/22...
# INFO - Quantizing self_attn.o_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 18/22...
# INFO - Quantizing mlp.up_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 18/22...
# INFO - Quantizing mlp.gate_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 18/22...
# INFO - Quantizing mlp.down_proj in layer 18/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 18/22...
# INFO - Start quantizing layer 19/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 19/22
# INFO - Quantizing self_attn.k_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 19/22...
# INFO - Quantizing self_attn.v_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 19/22...
# INFO - Quantizing self_attn.q_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 19/22...
# INFO - Quantizing self_attn.o_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 19/22...
# INFO - Quantizing mlp.up_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 19/22...
# INFO - Quantizing mlp.gate_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 19/22...
# INFO - Quantizing mlp.down_proj in layer 19/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 19/22...
# INFO - Start quantizing layer 20/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 20/22
# INFO - Quantizing self_attn.k_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 20/22...
# INFO - Quantizing self_attn.v_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 20/22...
# INFO - Quantizing self_attn.q_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 20/22...
# INFO - Quantizing self_attn.o_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 20/22...
# INFO - Quantizing mlp.up_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 20/22...
# INFO - Quantizing mlp.gate_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 20/22...
# INFO - Quantizing mlp.down_proj in layer 20/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 20/22...
# INFO - Start quantizing layer 21/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 21/22
# INFO - Quantizing self_attn.k_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 21/22...
# INFO - Quantizing self_attn.v_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 21/22...
# INFO - Quantizing self_attn.q_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 21/22...
# INFO - Quantizing self_attn.o_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 21/22...
# INFO - Quantizing mlp.up_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 21/22...
# INFO - Quantizing mlp.gate_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 21/22...
# INFO - Quantizing mlp.down_proj in layer 21/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 21/22...
# INFO - Start quantizing layer 22/22
# INFO:auto_gptq.modeling._base:Start quantizing layer 22/22
# INFO - Quantizing self_attn.k_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.k_proj in layer 22/22...
# INFO - Quantizing self_attn.v_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.v_proj in layer 22/22...
# INFO - Quantizing self_attn.q_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.q_proj in layer 22/22...
# INFO - Quantizing self_attn.o_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing self_attn.o_proj in layer 22/22...
# INFO - Quantizing mlp.up_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.up_proj in layer 22/22...
# INFO - Quantizing mlp.gate_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.gate_proj in layer 22/22...
# INFO - Quantizing mlp.down_proj in layer 22/22...
# INFO:auto_gptq.modeling._base:Quantizing mlp.down_proj in layer 22/22...
# WARNING - you are using save_pretrained, which will re-direct to save_quantized.
# WARNING:auto_gptq.modeling._base:you are using save_pretrained, which will re-direct to save_quantized.
# Saving gptq model to TinyLlama-1.1B-Chat-v1.0-gptq
# 2719

# %% [markdown]
# ## Convert the GPTQ model to Marlin format
#
# Next we want to convert the GPTQ formatted model into the optimized Marlin format. This is as simple as re-using `AutoGPTQForCausalLM.from_quantized` with the `use_marlin=True` argument, then saving back to disk.

# %%
print("Reloading in marlin format")
marlin_model = AutoGPTQForCausalLM.from_quantized(
    gptq_save_dir,
    use_marlin=True,
    device_map="auto")

marlin_save_dir = f"{MODEL_ID.split('/')[-1]}-marlin"
print(f"Saving model in marlin format to {marlin_save_dir}")
marlin_model.save_pretrained(marlin_save_dir)
tokenizer.save_pretrained(marlin_save_dir)
# Out:
# WARNING - ignoring unknown parameter in quantize_config.json: quant_method.
# WARNING:auto_gptq.modeling._base:ignoring unknown parameter in quantize_config.json: quant_method.
# INFO - The layer lm_head is not quantized.
# INFO:auto_gptq.modeling._base:The layer lm_head is not quantized.
# Reloading in marlin format
# Repacking weights to be compatible with Marlin kernel...: 100%|██████████| 314/314 [00:26<00:00, 11.97it/s]
# WARNING:accelerate.utils.modeling:The safetensors archive passed at TinyLlama-1.1B-Chat-v1.0-gptq/autogptq_model.safetensors does not contain metadata. Make sure to save your model with the `save_pretrained` method. Defaulting to 'pt' metadata.
# WARNING - you are using save_pretrained, which will re-direct to save_quantized.
# WARNING:auto_gptq.modeling._base:you are using save_pretrained, which will re-direct to save_quantized.
# Saving model in marlin format to TinyLlama-1.1B-Chat-v1.0-marlin
# ('TinyLlama-1.1B-Chat-v1.0-marlin/tokenizer_config.json',
#  'TinyLlama-1.1B-Chat-v1.0-marlin/special_tokens_map.json',
#  'TinyLlama-1.1B-Chat-v1.0-marlin/tokenizer.model',
#  'TinyLlama-1.1B-Chat-v1.0-marlin/added_tokens.json',
#  'TinyLlama-1.1B-Chat-v1.0-marlin/tokenizer.json')

# %% [markdown]
# **Optional**: You can upload your now optimally compressed 4-bit directly to Hugging Face, which makes it easy to keep up with all your compressed model variations and then deploy with nm-vllm on new systems.

# %%
# Upload the output model to Hugging Face Hub
from huggingface_hub import HfApi

final_model_name = "nm-testing/TinyLlama-1.1B-Chat-v1.0-marlin"

HfApi().upload_folder(
    folder_path=marlin_save_dir,
    repo_id=final_model_name,
)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/763M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nm-testing/TinyLlama-1.1B-Chat-v1.0-marlin/commit/5059cf5d5e58b61d8941baa9e52638eaea2e0335', commit_message='Upload folder using huggingface_hub', commit_description='', oid='5059cf5d5e58b61d8941baa9e52638eaea2e0335', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Optimized deployment with nm-vllm
#
# The [nm-vllm](https://github.com/neuralmagic/nm-vllm) package is a high-throughput and memory-efficient inference and serving engine for LLMs. It holds the latest LLM optimizations, such as the highly performant 4-bit Marlin CUDA kernels.
#
# To run a Marlin-optimized model with `nm-vllm`, simply pass the model in and the engine will automatically detect the quantization from the `config.json`.

# %%
# !pip install nm-vllm --extra-index-url https://pypi.neuralmagic.com/simple
# Out:
# Collecting nm-vllm
#   Downloading nm_vllm-0.1.0-cp310-cp310-manylinux_2_17_x86_64.whl (58.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 MB 12.1 MB/s eta 0:00:00
# Collecting ninja (from nm-vllm)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (5.9.5)
# Collecting ray>=2.9 (from nm-vllm)
#   Downloading ray-2.9.3-cp310-cp310-manylinux2014_x86_64.whl (64.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 MB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (1.25.2)
# Collecting torch==2.1.2 (from nm-vllm)
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (4.38.1)
# Collecting xformers==0.0.23.post1 (from nm-vllm)
#   Downloading xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (213.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 7.5 MB/s eta 0:00:00
# Collecting fastapi (from nm-vllm)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 13.7 MB/s eta 0:00:00
# Collecting uvicorn[standard] (from nm-vllm)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (2.6.3)
# Collecting aioprometheus[starlette] (from nm-vllm)
#   Downloading aioprometheus-23.12.0-py3-none-any.whl (31 kB)
# Collecting pynvml==11.5.0 (from nm-vllm)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: triton>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from nm-vllm) (2.2.0)
# Collecting cupy-cuda12x==12.1.0 (from nm-vllm)
#   Downloading cupy_cuda12x-12.1.0-cp310-cp310-manylinux2014_x86_64.whl (83.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x==12.1.0->nm-vllm) (0.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.2->nm-vllm)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->nm-vllm) (12.1.105)
# Collecting triton>=2.1.0 (from nm-vllm)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->nm-vllm) (12.3.101)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->nm-vllm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->nm-vllm) (2.16.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (8.1.7)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (1.0.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->nm-vllm) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->nm-vllm) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->nm-vllm) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->nm-vllm) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->nm-vllm) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->nm-vllm) (4.66.2)
# Collecting orjson (from aioprometheus[starlette]->nm-vllm)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 18.9 MB/s eta 0:00:00
# Collecting quantile-python>=1.1 (from aioprometheus[starlette]->nm-vllm)
#   Downloading quantile-python-1.1.tar.gz (2.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting starlette>=0.14.2 (from aioprometheus[starlette]->nm-vllm)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.8 MB/s eta 0:00:00
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.6 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn[standard]->nm-vllm)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]->nm-vllm)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 40.9 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->nm-vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->nm-vllm)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 90.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]->nm-vllm)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.8 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]->nm-vllm)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette>=0.14.2->aioprometheus[starlette]->nm-vllm) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.2->nm-vllm) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->nm-vllm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->nm-vllm) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->nm-vllm) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->nm-vllm) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->nm-vllm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->nm-vllm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->nm-vllm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->nm-vllm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.2->nm-vllm) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.14.2->aioprometheus[starlette]->nm-vllm) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.14.2->aioprometheus[starlette]->nm-vllm) (1.2.0)
# Building wheels for collected packages: quantile-python
#   Building wheel for quantile-python (setup.py) ... done
#   Created wheel for quantile-python: filename=quantile_python-1.1-py3-none-any.whl size=3444 sha256=81590896772fd6382cc7eed0f3da526be5062f6c0b4a1d1421198365f7b2270c
#   Stored in directory: /root/.cache/pip/wheels/6d/f4/0a/0e7d01548a005f9f3fa23101f071d248da052f2a9bf2fe11c6
# Successfully built quantile-python
# Installing collected packages: quantile-python, ninja, websockets, uvloop, triton, python-dotenv, pynvml, orjson, nvidia-nccl-cu12, httptools, h11, cupy-cuda12x, watchfiles, uvicorn, starlette, aioprometheus, torch, fastapi, xformers, ray, nm-vllm
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.19.3
#     Uninstalling nvidia-nccl-cu12-2.19.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.19.3
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 12.2.0
#     Uninstalling cupy-cuda12x-12.2.0:
#       Successfully uninstalled cupy-cuda12x-12.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed aioprometheus-23.12.0 cupy-cuda12x-12.1.0 fastapi-0.110.0 h11-0.14.0 httptools-0.6.1 ninja-1.11.1.1 nm-vllm-0.1.0 nvidia-nccl-cu12-2.18.1 orjson-3.9.15 pynvml-11.5.0 python-dotenv-1.0.1 quantile-python-1.1 ray-2.9.3 starlette-0.36.3 torch-2.1.2 triton-2.1.0 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0 xformers-0.0.23.post1

# %% [markdown]
# Now we can simply pass in the quantized Marlin model we just made to use directly within the engine.

# %%
from vllm import LLM, SamplingParams

prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.8, top_p=0.95, max_tokens=100)

# Create an LLM.
llm = LLM("nm-testing/TinyLlama-1.1B-Chat-v1.0-marlin")

# Generate texts from the prompts. The output is a list of RequestOutput objects
# that contain the prompt, generated text, and other information.
outputs = llm.generate(prompts, sampling_params)

# Print the outputs.
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"\nGenerated text: {prompt}{generated_text}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# INFO 03-05 19:29:18 llm_engine.py:81] Initializing an LLM engine with config: model='nm-testing/TinyLlama-1.1B-Chat-v1.0-marlin', tokenizer='nm-testing/TinyLlama-1.1B-Chat-v1.0-marlin', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=marlin, sparsity=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=0)
# INFO 03-05 19:29:22 weight_utils.py:177] Using model weights format ['*.safetensors']
# INFO 03-05 19:29:23 llm_engine.py:340] # GPU blocks: 102209, # CPU blocks: 11915
# INFO 03-05 19:29:26 model_runner.py:676] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 03-05 19:29:26 model_runner.py:680] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 03-05 19:29:32 model_runner.py:748] Graph capturing finished in 5 secs.
# Processed prompts: 100%|██████████| 4/4 [00:00<00:00,  6.51it/s]
# Generated text: Hello, my name is John Smith. And I’m a senior at your high school. I'm interested in learning more about your school and how it compares to other schools in our area. I've heard good things about your school, so I would appreciate it if you could give me some information on the facilities, the teachers, and the overall student body. Please provide me with specific examples of the academic programs and extracurricular activities that you offer, as well as any notable sports teams or clubs
#
#
# Generated text: The president of the United States is a member of the presidential Cabinet.
#
# 2. You may also be interested in learning about the role of the vice president, as well as their responsibilities and duties.
#
# 3. To learn more about the office of the president, you may want to explore our collection of articles, podcasts, and videos.
#
# 4. If you're looking for a guide to the US presidential elections, I would recommend checking out The Guardian's guide, which
#
#
# Generated text: The capital of France is Paris. The capital city of China is Beijing. The capital of Turkey is Ankara. The capital of India is New Delhi. The capital of Brazil is Brasilia. The capital of Singapore is Singapore. The capital of Malaysia is Kuala Lumpur. The capital of the United States is Washington, D.C. The capital of Canada is Ottawa. The capital of Switzerland is Zurich. The capital of Italy is Rome. The capital of Spain is Madrid
#
#
# Generated text: The future of AI is likely to bring about a proliferation of new technologies and techniques. Some of these advancements could have significant impacts on industries like healthcare, manufacturing, and education. However, there are also concerns about the potential negative consequences of AI technology, such as its impact on job opportunities and its ability to create artificial intelligence bubbles. Despite these concerns, there is no denying that AI has the potential to revolutionize the way we live, work,

# %% [markdown]
# For more details on how to deploy, go to the [nm-vllm Github repo](https://github.com/neuralmagic/nm-vllm).
#
# For further support, and discussions on these models and AI in general, join [Neural Magic's Slack Community](https://join.slack.com/t/discuss-neuralmagic/shared_invite/zt-q1a1cnvo-YBoICSIw3L1dmQpjBeDurQ)
